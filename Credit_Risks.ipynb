# %%
import pandas as pd

from sklearn.datasets import fetch_openml
dataset = fetch_openml(name='credit-g', version='1')
print(dataset)
# print(dataset.columns['checking-status'])
# df=pd.DataFrame(dataset)
# Out:
# {'data': array([[ 0.,  6.,  4., ...,  1.,  1.,  0.],
#        [ 1., 48.,  2., ...,  1.,  0.,  0.],
#        [ 3., 12.,  4., ...,  2.,  0.,  0.],
#        ...,
#        [ 3., 12.,  2., ...,  1.,  0.,  0.],
#        [ 0., 45.,  2., ...,  1.,  1.,  0.],
#        [ 1., 45.,  4., ...,  1.,  0.,  0.]]), 'target': array(['good', 'bad', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'bad', 'good', 'bad', 'good', 'bad', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'bad',
#        'good', 'good', 'bad', 'good', 'good', 'bad', 'bad', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
# ...

# %%
#Does the dataset include any missing values? If so, delete the missing values entries
df.isnull().sum(axis = 0)
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# employmnet                0
# dtype: int64

# %%
#preprocessing
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import LabelEncoder
dataset = fetch_openml(name='credit-g', version='1',as_frame=True)
x = dataset.data
z=dataset.frame
df=pd.DataFrame(z)
# print(z)
df.describe
encoder = LabelEncoder()
encoder.fit(df['class'])
df['class']= encoder.transform(df['class'])
encoder.fit(df['foreign_worker'])
df['foreign_worker']= encoder.transform(df['foreign_worker'])
encoder.fit(df['checking_status'])
df['checking_status']= encoder.transform(df['checking_status'])
encoder.fit(df['credit_history'])
df['credit_history']= encoder.transform(df['credit_history'])
encoder.fit(df['credit_amount'])
df['credit_amount']= encoder.transform(df['credit_amount'])
# print(dataset.feature_names)
encoder.fit(df['purpose'])
df['purpose']= encoder.transform(df['purpose'])
encoder.fit(df['savings_status'])
df['savings_status']= encoder.transform(df['savings_status'])
encoder.fit(df['employment'])
df['employmnet']= encoder.transform(df['employment'])
encoder.fit(df['installment_commitment'])
df['installment_commitment']= encoder.transform(df['installment_commitment'])
encoder.fit(df['personal_status'])
df['personal_status']= encoder.transform(df['personal_status'])
encoder.fit(df['other_parties'])
df['other_parties']= encoder.transform(df['other_parties'])
encoder.fit(df['residence_since'])
df['residence_since']= encoder.transform(df['residence_since'])
encoder.fit(df['property_magnitude'])
df['property_magnitude']= encoder.transform(df['property_magnitude'])
encoder.fit(df['age'])
df['age']= encoder.transform(df['age'])
encoder.fit(df['job'])
df['job']= encoder.transform(df['job'])
encoder.fit(df['housing'])
df['housing']= encoder.transform(df['housing'])
encoder.fit(df['property_magnitude'])
df['property_magnitude']= encoder.transform(df['property_magnitude'])
encoder.fit(df['num_dependents'])
df['num_dependents']= encoder.transform(df['num_dependents'])
encoder.fit(df['own_telephone'])
df['own_telephone']= encoder.transform(df['own_telephone'])
encoder.fit(df['existing_credits'])
df['existing_credits']= encoder.transform(df['existing_credits'])
encoder.fit(df['other_payment_plans'])
df['other_payment_plans']= encoder.transform(df['other_payment_plans'])
print(dataset.feature_names)
  
print(df.purpose)
# Out:
# ['checking_status', 'duration', 'credit_history', 'purpose', 'credit_amount', 'savings_status', 'employment', 'installment_commitment', 'personal_status', 'other_parties', 'residence_since', 'property_magnitude', 'age', 'other_payment_plans', 'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone', 'foreign_worker']
# 0      6
# 1      6
# 2      2
# 3      3
# 4      4
#       ..
# 995    3
# 996    9
# 997    6
# 998    6
# 999    9
# Name: purpose, Length: 1000, dtype: int64

# %%
a=df[df.columns[1:]].corr() ['class'][:]
result=a[abs(a)>0.08]
result
df2=df[['duration','credit_history','purpose','credit_amount','savings_status','age','foreign_worker','class']]

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = (df2.iloc[:,1:])
y = df2.iloc[:, -1].values

# print(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.2, random_state=0)
X_test, X_val, y_test, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=1) 
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=9).fit(X_train, y_train)
score = model.score(X_test, y_test)
print('score ',score)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))

from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
conf = confusion_matrix(y_test, y_pred)
print(conf)



# search for an optimal value of K for KNN

# range of k we want to try
k_range = range(1, 15)
# empty list to store scores
k_scores = []

# 1. we will loop through reasonable values of k
for k in k_range:
    # 2. run KNeighborsClassifier with k neighbours
    knn = KNeighborsClassifier(n_neighbors=k)

    # 3. obtain cross_val_score for KNeighborsClassifier with k neighbours
    scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')
    # print(scores)
    # 4. append mean of scores for k neighbors to k_scores list
    k_scores.append(scores.mean())


print(k_scores)
print('best k:',(np.asarray(k_scores,dtype=float)).argmax()-1)
# Out:
# score  0.72
# accuracy_score: 0.72
# [[ 33  95]
#  [ 17 255]]
# [0.615, 0.545, 0.639, 0.589, 0.6569999999999999, 0.631, 0.667, 0.6339999999999999, 0.6769999999999999, 0.65, 0.6849999999999999, 0.6729999999999999, 0.681, 0.667]
# best k: 9
